# %%
import pandas as pd
import numpy as np

np.random.seed(0)

n = 1500

df = pd.DataFrame({
    "age_group" : np.random.choice(
        ["18-34", "35-49", "50-64", "65+"],
        size = n,
        p=[0.3, 0.25, 0.25, 0.2]
    ),
    "sex": np.random.choice(["Female", "Male"], size=n),
    "insurance": np.random.choice(
        ["Private", "Public", "Uninsured"], 
        size=n, 
        p=[0.5, 0.35, 0.15]
    ),
    "preventive_visit": np.random.choice(
        ["Yes", "No"], 
        size=n, 
        p=[0.55, 0.45]
    )
})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 9
#       4 np.random.seed(0)
#       6 n = 1500
#       8 df = pd.DataFrame({
# ----> 9     "age_group" : np.random.choise(
#      10         ["18-34", "35-49", "50-64", "65+"],
#      11         size = n,
#      12         p=[0.3, 0.25, 0.25, 0.2]
#      13     ),
#      14     "sex": np.random.choice(["Female", "Male"], size=n),
#      15     "insurance": np.random.choice(
#      16         ["Private", "Public", "Uninsured"],
#      17         size=n,
#      18         p=[0.5, 0.35, 0.15]
#      19     ),
#      20     "preventive_visit": np.random.choice(
#      21         ["Yes", "No"],
#      22         size=n,
#      23         p=[0.55, 0.45]
#      24     )
#      25 })
#
# AttributeError: module 'numpy.random' has no attribute 'choise'
